# %% [markdown]
# Oracle in Education
# ======
# * Includes computer science clubs
# * Java and APCS curriculum
# * Java Development Environments: Alice, Greenfoot, BlueJ, Eclipse, Netbeans
# * Intro to CS, AP CS, Business curriculum
# * Integrating STEM into Liberal Arts and Sciences

# %% [markdown]
# North American Wildlife Project
# ======
# * Milestones - research, self-study, storyboard for game, storyboard for quiz, refine storyboard, develop questions, develop and present animation
# * This could be modified to prepare study materials for a class at a neighboring school
# * Oracle online has templates for storyboards
# * Game could be used as a POGIL prep
# * Project and project manager, different roles, use as instructional piece for project management

# %% [markdown]
# Alice - Needs Reflection Guides
# ======
# Dennis.cosgrove@gmail.com

# %%
from IPython.display import Image

Image(filename="files/octocat.jpg")
